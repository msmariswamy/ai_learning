# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name = (input)("Enter your institute name? :")
# Out:
# Enter your institute name? : AI

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
schoolName = input("Enter your school name: ")
Degree = input("Enter your drgree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru Scheeol
# Enter your drgree:  BE CSE

# %%
a= 43
b= 34
add = a+b
print("add = ",add)
# Out:
# add =  77

# %%
a= 43
b= 34
Sub = a-b
print("Sub = ", Sub)
# Out:
# Sub =  9
